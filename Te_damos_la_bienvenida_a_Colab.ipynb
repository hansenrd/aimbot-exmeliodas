# %% [markdown]
# <a href="https://colab.research.google.com/github/hansenrd/aimbot-exmeliodas/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Te damos la bienvenida a Colab

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.9 MB/s eta 0:00:00
# ...

# %%
# !unzip bv13.zip
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: test/labels/capture_00070_20250831_045906_247_jpg.rf.b8c870e18fa35bdef1c03a63c144c804.txt
#   inflating: test/labels/aa7a2229-ef60-48f8-be89-b6df350e3dfe_jpg.rf.225c85b83d425d4092b2e01acfc0714f.txt
#   inflating: test/labels/0dc455a8-b205-4812-8dce-85255fdb2f9d_jpg.rf.17808f070ce71af3b369541d383a7539.txt
#   inflating: test/labels/d56eb55f-52cb-4a6f-8c8b-afac67056fe7_jpg.rf.26330f7994d794db0239dbe4162450cf.txt
#   inflating: test/labels/maxquality_capture_00021_20250902_181746_677_png.rf.dea6213c1ddc1ed3b23158329eba646f.txt
#   inflating: test/labels/598a5557-3d00-4c0e-920a-cd4ce71ea029_jpg.rf.401e2a128b27faf33e15fcf5fec0f746.txt
#   inflating: test/labels/BLOOD-STRIKE-61-KILLS-NEW-UPDATE-NEW-FREE-ETERNAL-DESERT-EAGLE-SCORPIUS-MAX-GRAPHICS-RTX-4060-Edwin-Wijaya-1440p-_mp4-1046_jpg.rf.3bf2b129df1e242b8a36b86fa8f469f4.txt
# ...

# %%
# !yolo detect train \
data=data.yaml \
model=yolov8s.pt \
epochs=30 \
imgsz=640 \
batch=16 \
cache=True \
workers=8 \
amp=True
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
